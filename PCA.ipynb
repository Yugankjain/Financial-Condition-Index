# %%
from sklearn.decomposition import PCA
import pandas as pd

# %%
train = pd.read_csv('../input/complete-var/FCI DATA csv wala.csv')

# %%
train.head()

# %%
pca = PCA(n_components=3)

# %%
pca.fit(train.drop(columns = ['Date']))

# %%
a = pca.components_

# %%
a = pca.components_

# %%
x = (a[0]+a[1]+a[2])/3

# %%
import numpy

# %%
z = 1/(1 + numpy.exp(-x))

# %%
b = z/sum(z)

# %%
b
